# %% [markdown]
# conda install -c conda-forge feature_engine**Primeramente vamos a realizar la instalación e importación de las librerias necesarias para el desarrollo de la práctica**

# %%
conda install -c conda-forge feature_engine
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import math

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge, LinearRegression, Lasso
from sklearn.feature_selection import f_classif, mutual_info_classif
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score


from feature_engine.encoding import MeanEncoder

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Realizamos la lectura del csv que vamos a analizar y lo guardamos en una variable(full_df). Como el análisis lo vamos a realizar sobre las viviendas de Madrid, antes de realizar
# la división en train y test filtramos para obtener unicamente las viviendas de interés**

# %%
full_df = pd.read_csv('dataframes/airbnb-listings-extract.csv', sep=';', decimal='.')

# %% [markdown]
# **En las siguientes celdas vamos a realizar el filtrado del dataframe inicial para obtener unicamente alojamientos que estén ubicados en Madrid y la posterior división del dataframe en train y test para su guardado en formato csv**

# %%
print('Comprobamos cuantas ciudades hay en el dataframe \n')
pd.options.display.max_rows=30
print(full_df['City'].value_counts())
#Vamos a filtrar la columna city obteniendo las filas que contengan la palabra madrid
full_df['City'] = full_df['City'].fillna('')
full_df_madrid = full_df[full_df.City.str.contains('madrid', case=False)]
print('-----------------------------------------------\n')
print(f'Tras el filtrado realizado teniendo en cuenta unicamente la ciudad de Madrid hemos eliminado el {round(((full_df.shape[0]-full_df_madrid.shape[0])/full_df.shape[0])*100,2)}% de las filas.')
# Out:
# Comprobamos cuantas ciudades hay en el dataframe
#
# Madrid            13207
# Barcelona           292
# London              132
# Paris               108
# 马德里                  52
#                   ...
# Son Moll              1
# La Habana             1
# Mile End / Bow        1
# Sint-Gillis           1
# Son Vida              1
# Name: City, Length: 246, dtype: int64
# -----------------------------------------------
#
# Tras el filtrado realizado teniendo en cuenta unicamente la ciudad de Madrid hemos eliminado el 10.39% de las filas.

# %%
train, test = train_test_split(full_df_madrid, test_size=0.2, shuffle=True, random_state=0)

print(f'Dimensiones del dataset de training: {train.shape}')
print(f'Dimensiones del dataset de test: {test.shape}')

# Guardamos
train.to_csv('dataframes/train.csv', sep=';', decimal='.', index=False)
test.to_csv('dataframes/test.csv', sep=';', decimal='.', index=False)
# Out:
# Dimensiones del dataset de training: (10596, 89)
# Dimensiones del dataset de test: (2649, 89)

# %% [markdown]
# **Antes de empezar a realizar el análisis exploratorio vamos a crear unas funciones que nos ayudaran en el análisis**
#
# **Funciones para graficar**

# %% [markdown]
# La siguiente función genera gráficas de como se distribuye la variable en su forma original, cuadrática y logarítmica

# %%
def price_distribution(df):
    fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
    sns.distplot(
        df.Price,
        hist    = False,
        rug     = True,
        color   = "blue",
        kde_kws = {'shade': True, 'linewidth': 1},
        ax      = axes[0]
    )
    axes[0].set_title("Distribución original", fontsize = 'medium')
    axes[0].set_xlabel('Price', fontsize='small') 
    axes[0].tick_params(labelsize = 6)

    sns.distplot(
        np.sqrt(df.Price),
        hist    = False,
        rug     = True,
        color   = "blue",
        kde_kws = {'shade': True, 'linewidth': 1},
        ax      = axes[1]
    )
    axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
    axes[1].set_xlabel('sqrt(precio)', fontsize='small') 
    axes[1].tick_params(labelsize = 6)

    sns.distplot(
        np.log(df.Price),
        hist    = False,
        rug     = True,
        color   = "blue",
        kde_kws = {'shade': True, 'linewidth': 1},
        ax      = axes[2]
    )
    axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
    axes[2].set_xlabel('log(precio)', fontsize='small') 
    axes[2].tick_params(labelsize = 6)

    fig.tight_layout()

# %% [markdown]
# La siguiente es una función a la que pasandolo por argumento el df y las columnas a graficar te genera los histogramas:

# %%
def create_hist(df, columns=None):
    """ Función que crea los histogramas en subplots. la función calcula el numero de filas a generar y extrae las columnas numéricas del dataframe por defecto
        Si solo se quiere graficar ciertas dimensiones se puede pasar por parametro en forma de lista:
        df= df de pandas
        columns=None graficará todo el df, se puede pasar lista con dim a graficar"""   
    num_columns= df[columns].colums if columns else df.select_dtypes(include=['float64', 'int64']).columns.drop('Price')
    size= math.ceil(len(num_columns)/3)
    fig, axes = plt.subplots(nrows=size, ncols=3, figsize=(18, 5*size))
    axes = axes.flat
    fig.suptitle('Distribución variables numéricas',va='top', y= 1,fontsize = 18)
    for i, col in enumerate(num_columns):
        sns.histplot(
            data    = df,
            x       = col,
            stat    = "count",
            kde     = True,
            color   = (list(plt.rcParams['axes.prop_cycle'])*2)[i]["color"],
            line_kws= {'linewidth': 2},
            alpha   = 0.3,
            ax      = axes[i]
        )
        axes[i].set_title(col, fontsize = 12)
        axes[i].tick_params(labelsize = 10)
        plt.subplots_adjust(top=0.9)
        axes[i].set_xlabel("")
        fig.tight_layout()
     #Borramos los subplots que queden vacios
    graf_del = size*3 - len(num_columns)
    if graf_del == 1 :
        fig.delaxes(axes[-1])
    if graf_del == 2 :
        fig.delaxes(axes[-1])
        fig.delaxes(axes[-2])

# %% [markdown]
# La siguiente es una función a la que pasandolo por argumento el df y las columnas a graficar te genera los scatter:

# %%
def create_scatter(df, columns=None, y = 'Price'):
    """ Función que crea los scatter en subplots. la función calcula el numero de filas a generar y extrae las columnas numéricas del dataframe por defecto
        Por defecto te realizará la comparación con la variable Price, si se desea compara con otra variable se le puede pasar por parámetro como y
        Si solo se quiere graficar ciertas dimensiones se puede pasar por parametro en forma de lista:
        df= df de pandas
        columns=None graficará todo el df, se puede pasar lista con dim a graficar
        y = 'Price' Valor por defecto de la columna buscada"""
    num_columns = df[columns].columns if columns else df.select_dtypes(include=['float64', 'int64']).columns.drop(y)
    size= math.ceil(len(num_columns)/3)
    fig, axes = plt.subplots(nrows=size, ncols=3, figsize=(16, 5*size))
    axes = axes.flat
    fig.suptitle('Relación entre variables',va='top', y= 1,fontsize = 18)
    for i, colum in enumerate(num_columns):
        sns.regplot(
            x           = df[colum],
            y           = df[y],
            color       = "gray",
            marker      = '.',
            scatter_kws = {"alpha":0.4},
            line_kws    = {"color":"r","alpha":0.5},
            ax          = axes[i]
        )
        axes[i].set_title(f"{y} vs {colum}", fontsize = 12)
        axes[i].tick_params(labelsize = 10)
        axes[i].set_xlabel("")
        axes[i].set_ylabel("")
    fig.tight_layout()
    #Borramos los subplots que queden vacios
    graf_del = size*3 - len(num_columns)
    if graf_del == 1 :
        fig.delaxes(axes[-1])
    if graf_del == 2 :
        fig.delaxes(axes[-1])
        fig.delaxes(axes[-2])

# %% [markdown]
# La siguiente función nos genera los gráficos boxplot

# %%
def create_boxplot(df, columns = None):
    """Funcion que genera por defecto dibuja graficos boxplot de todos las dimensiones de df con tipo ['object', 'uint8'], si se le pasa una lista con 
    dimensiones del df unicamente graficará dicha lista:
        df = dataframe de pandas
        columns = None por defecto grafica todo el df, lista de dimensiones que quiers graficar
        """
    
    object_columns= df[columns].columns if columns else df.select_dtypes(include=['object', 'uint8']).columns
    #Para realizar una buena visualizacion de los dummies vamos a eliminar del conteo para las filas los dummies que representan los SI
    columns_to_drop = [col for col in object_columns if ("_NO") in col]  
    object_columns = object_columns.drop(columns_to_drop) if columns_to_drop else  object_columns
    size= math.ceil(len(object_columns)/2)
    fig, axes= plt.subplots(nrows=size, ncols=2, figsize=(16, 6*size))
    axes = axes.flat
    fig.suptitle('Distribución del precio por variable categórica',va='top', y= 1,fontsize = 18)
    for i, col in enumerate(object_columns):
        if df[col].dtypes == 'object':  
            sns.boxplot(data= df,
                        x           = 'Price',
                        y           = col,
                        width       = 0.7,
                        ax          = axes[i]
                )
            axes[i].set_title(f"{col}", fontsize = 12)
            axes[i].tick_params(labelsize = 10)
            axes[i].set_xlabel("")
            axes[i].set_ylabel("")    
            
        if df[col].dtypes == 'uint8':            
            sns.boxplot(data= df,
                        x           = col,
                        y           = 'Price',
                        width       = 0.7,
                        ax          = axes[i]
                )
            axes[i].set_title(f"{col[:-3]} (NO=0 SI=1)", fontsize = 12)
            axes[i].tick_params(labelsize = 10)
            axes[i].set_xlabel("")
            axes[i].set_ylabel("")               
    
    fig.tight_layout()
    #Borramos los subplots que queden vacios
    graf_del = size*2 - len(object_columns)
    if graf_del == 1 :
        fig.delaxes(axes[-1])

# %% [markdown]
# La siguiente funcion dibuja la distribución de las variables cuantitativas

# %%
def create_dist_categ(df, columns = None):
    object_columns= df[columns].columns if columns else df.select_dtypes(include=['object']).columns
    size= math.ceil(len(object_columns)/2)
    fig, axes= plt.subplots(nrows=size, ncols=2, figsize=(16, 6*size))
    axes = axes.flat
    columnas_object = df.select_dtypes(include=['object']).columns
    fig.suptitle('Distribución variables categóricas',fontsize = 18)
    for i, colum in enumerate(columnas_object):
        df[colum].value_counts().plot.barh(ax = axes[i])
        axes[i].set_title(colum, fontsize = 12)
        axes[i].tick_params(labelsize = 10)
        axes[i].set_xlabel("")

    # Se eliminan los axes vacíos
    graf_del = size*2 - len(object_columns)
    if graf_del == 1 :
        fig.delaxes(axes[-1])

    fig.tight_layout()
    plt.subplots_adjust(top=0.9)

# %%
def corr_matrix(df):
    """función que calcula la matriz de correlación de las dimensiones numéricas de un df
    df = dataframe de pandas"""
    num_colums = df.select_dtypes(include=['float64', 'int64'])
    corr = np.abs(num_colums.drop(['Price'], axis=1).corr())

    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(8, 8))

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5, annot = True,
                linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})
    f.suptitle('Matriz de correlación', fontsize=18)
    plt.show()

# %% [markdown]
# **Funciones para trasnformar DF**

# %% [markdown]
# La siguient función elimina columnas del dataframe

# %%
def first_trasnformation(df,colums_to_remove):
    """Función a la que le pasamos el df a tratar y una lista con los nombres de las columnas a borrar
        df = dataframe de pandas
        colums_to_remove = lista de las columnas a eliminar"""
    return df.drop(colums_to_remove,axis=1)

# %% [markdown]
# La siguiente función realiza varias modificaciones, por un lado modifica la dimensión Security Deposit, cambiandola a categórica (SI/NO), realizando la suposición de que los valores NA indican que no se requiere fianza. Por otro lado realiza una busqueda en la columna de Amenities para saber si el alojamiento tiene aire acondicionado y calefacción creando dos columnas en donde indica (SI/NO). y por último convierte a dummies las 3 columnas trasnformadas

# %%
def second_transformation(df):
    """Función que crea las dummies tras trasnformar a categóricas 3 dimensiones, la existencia de A/C, la existencia calfaccción en la vivienda y 
    si se cobra o no fianza. Por último elimina la columna Amenities
        df= dataframe de pandas"""
    
    df['Security Deposit'] = df['Security Deposit'].map(lambda x: 'SI' if x>0 else 'NO')
    condition_heat = df['Amenities'].str.contains('heating', case=False)
    condition_air = df['Amenities'].str.contains('Air conditioning', case=False)
    df['Heating'] = np.where(condition_heat, 'SI','NO')
    df['Air conditioning'] = np.where(condition_air, 'SI','NO')
    #Trasnforma las 3 columnas anteriores a dummies
    df = pd.get_dummies(df,prefix=['A/C','Heat','Sec_Dep'],columns=['Air conditioning','Heating','Security Deposit'])
    return df.drop('Amenities', axis=1)

# %% [markdown]
# La siguiente función reagrupa niveles de variables categóricas para eliminar una granulación excesiva

# %%
def regroup_values(df,column,list_index, new_value = 'Other'):    
    """Esta función realiza una reagrupación de niveles de una columna de variable categórica:
        df = dataframe de pandas
        column = columna a modificar 
        list_index = lista de valores que se mantendrán, al resto que no se correspondan con la lista les pondrá el valor other por defecto
        new_value = 'Other' valor que añadirá por defecto"""
    df[column] = [new_value if x not in list_index else x for x in df[column]]

# %% [markdown]
# **Realizamos la carga del archivo csv y lo guardamos en una variable llamada df**

# %%
df = pd.read_csv('dataframes/train.csv', sep=';', decimal='.')

# %% [markdown]
# **En el siguiente paso vamos a realizar un análisis exploratorio del df de train con el que vamos a trabajar**

# %% [markdown]
# En primer lugar vamos a ver como se distribuye la variable buscada mediante gráficas de densidad de probabilidad

# %%
price_distribution(df)

# %%
pd.options.display.max_rows=None 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10596 entries, 0 to 10595
# Data columns (total 89 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              10596 non-null  int64
#  1   Listing Url                     10596 non-null  object
#  2   Scrape ID                       10596 non-null  int64
#  3   Last Scraped                    10596 non-null  object
#  4   Name                            10596 non-null  object
#  5   Summary                         10202 non-null  object
#  6   Space                           7731 non-null   object
#  7   Description                     10593 non-null  object
#  8   Experiences Offered             10596 non-null  object
#  9   Neighborhood Overview           6620 non-null   object
#  10  Notes                           4026 non-null   object
#  11  Transit                         6577 non-null   object
#  12  Access                          6020 non-null   object
#  13  Interaction                     5979 non-null   object
#  14  House Rules                     6892 non-null   object
#  15  Thumbnail Url                   8587 non-null   object
#  16  Medium Url                      8587 non-null   object
#  17  Picture Url                     10581 non-null  object
#  18  XL Picture Url                  8587 non-null   object
#  19  Host ID                         10596 non-null  int64
#  20  Host URL                        10596 non-null  object
#  21  Host Name                       10593 non-null  object
#  22  Host Since                      10593 non-null  object
#  23  Host Location                   10560 non-null  object
#  24  Host About                      6589 non-null   object
#  25  Host Response Time              9278 non-null   object
#  26  Host Response Rate              9278 non-null   float64
#  27  Host Acceptance Rate            0 non-null      float64
#  28  Host Thumbnail Url              10593 non-null  object
#  29  Host Picture Url                10593 non-null  object
#  30  Host Neighbourhood              7989 non-null   object
#  31  Host Listings Count             10593 non-null  float64
#  32  Host Total Listings Count       10593 non-null  float64
#  33  Host Verifications              10591 non-null  object
#  34  Street                          10596 non-null  object
#  35  Neighbourhood                   7013 non-null   object
#  36  Neighbourhood Cleansed          10596 non-null  object
#  37  Neighbourhood Group Cleansed    10596 non-null  object
#  38  City                            10596 non-null  object
#  39  State                           10561 non-null  object
#  40  Zipcode                         10249 non-null  object
#  41  Market                          10553 non-null  object
#  42  Smart Location                  10596 non-null  object
#  43  Country Code                    10596 non-null  object
#  44  Country                         10596 non-null  object
#  45  Latitude                        10596 non-null  float64
#  46  Longitude                       10596 non-null  float64
#  47  Property Type                   10596 non-null  object
#  48  Room Type                       10596 non-null  object
#  49  Accommodates                    10596 non-null  int64
#  50  Bathrooms                       10559 non-null  float64
#  51  Bedrooms                        10580 non-null  float64
#  52  Beds                            10558 non-null  float64
#  53  Bed Type                        10596 non-null  object
#  54  Amenities                       10505 non-null  object
#  55  Square Feet                     424 non-null    float64
#  56  Price                           10588 non-null  float64
#  57  Weekly Price                    2680 non-null   float64
#  58  Monthly Price                   2645 non-null   float64
#  59  Security Deposit                4479 non-null   float64
#  60  Cleaning Fee                    6241 non-null   float64
#  61  Guests Included                 10596 non-null  int64
#  62  Extra People                    10596 non-null  int64
#  63  Minimum Nights                  10596 non-null  int64
#  64  Maximum Nights                  10596 non-null  int64
#  65  Calendar Updated                10596 non-null  object
#  66  Has Availability                0 non-null      float64
#  67  Availability 30                 10596 non-null  int64
#  68  Availability 60                 10596 non-null  int64
#  69  Availability 90                 10596 non-null  int64
#  70  Availability 365                10596 non-null  int64
#  71  Calendar last Scraped           10596 non-null  object
#  72  Number of Reviews               10596 non-null  int64
#  73  First Review                    8400 non-null   object
#  74  Last Review                     8399 non-null   object
#  75  Review Scores Rating            8300 non-null   float64
#  76  Review Scores Accuracy          8287 non-null   float64
#  77  Review Scores Cleanliness       8294 non-null   float64
#  78  Review Scores Checkin           8284 non-null   float64
#  79  Review Scores Communication     8294 non-null   float64
#  80  Review Scores Location          8283 non-null   float64
#  81  Review Scores Value             8282 non-null   float64
#  82  License                         205 non-null    object
#  83  Jurisdiction Names              0 non-null      float64
#  84  Cancellation Policy             10596 non-null  object
#  85  Calculated host listings count  10596 non-null  float64
#  86  Reviews per Month               8400 non-null   float64
#  87  Geolocation                     10596 non-null  object
#  88  Features                        10596 non-null  object
# dtypes: float64(26), int64(13), object(50)
# memory usage: 7.2+ MB

# %%
pd.options.display.max_columns=None 
df.describe().T
# Out:
#                                   count          mean           std  \
# ID                              10596.0  1.040393e+07  5.520123e+06
# Scrape ID                       10596.0  2.017041e+13  4.343955e+00
# Host ID                         10596.0  3.735013e+07  3.435663e+07
# Host Response Rate               9278.0  9.483994e+01  1.524988e+01
# Host Acceptance Rate                0.0           NaN           NaN
# Host Listings Count             10593.0  9.799113e+00  2.774508e+01
# Host Total Listings Count       10593.0  9.799113e+00  2.774508e+01
# Latitude                        10596.0  4.042052e+01  2.015372e-02
# Longitude                       10596.0 -3.697153e+00  2.356882e-02
# Accommodates                    10596.0  3.190260e+00  2.000907e+00
# Bathrooms                       10559.0  1.251776e+00  6.024830e-01
# Bedrooms                        10580.0  1.291210e+00  8.227886e-01
# Beds                            10558.0  1.991760e+00  1.527565e+00
# Square Feet                       424.0  3.603726e+02  5.452669e+02
# Price                           10588.0  6.606895e+01  5.641459e+01
# Weekly Price                     2680.0  3.686313e+02  1.909059e+02
# Monthly Price                    2645.0  1.346080e+03  1.002043e+03
# Security Deposit                 4479.0  1.832438e+02  1.088107e+02
# Cleaning Fee                     6241.0  2.949207e+01  2.572034e+01
# Guests Included                 10596.0  1.573801e+00  1.076905e+00
# Extra People                    10596.0  7.413364e+00  1.053055e+01
# Minimum Nights                  10596.0  3.001038e+00  1.330001e+01
# Maximum Nights                  10596.0  9.777488e+02  9.914065e+03
# Has Availability                    0.0           NaN           NaN
# Availability 30                 10596.0  8.744054e+00  9.090992e+00
# Availability 60                 10596.0  2.292969e+01  1.953656e+01
# Availability 90                 10596.0  4.009532e+01  2.942206e+01
# Availability 365                10596.0  2.051368e+02  1.273751e+02
# Number of Reviews               10596.0  2.322093e+01  3.883293e+01
# Review Scores Rating             8300.0  9.171542e+01  8.766315e+00
# Review Scores Accuracy           8287.0  9.409798e+00  9.170473e-01
# Review Scores Cleanliness        8294.0  9.325778e+00  9.970261e-01
# Review Scores Checkin            8284.0  9.626268e+00  7.813568e-01
# Review Scores Communication      8294.0  9.644562e+00  7.431645e-01
# Review Scores Location           8283.0  9.544489e+00  7.665391e-01
# Review Scores Value              8282.0  9.214803e+00  9.430637e-01
# Jurisdiction Names                  0.0           NaN           NaN
# Calculated host listings count  10596.0  7.647131e+00  1.985653e+01
# Reviews per Month                8400.0  1.923152e+00  1.877670e+00
#
#                                          min           25%           50%  \
# ID                              1.862800e+04  5.786814e+06  1.152145e+07
# Scrape ID                       2.017041e+13  2.017041e+13  2.017041e+13
# Host ID                         1.745300e+04  7.649063e+06  2.734185e+07
# Host Response Rate              0.000000e+00  1.000000e+02  1.000000e+02
# Host Acceptance Rate                     NaN           NaN           NaN
# Host Listings Count             0.000000e+00  1.000000e+00  2.000000e+00
# Host Total Listings Count       0.000000e+00  1.000000e+00  2.000000e+00
# Latitude                        4.033189e+01  4.041005e+01  4.041865e+01
# Longitude                      -3.863907e+00 -3.707707e+00 -3.701551e+00
# Accommodates                    1.000000e+00  2.000000e+00  2.000000e+00
# Bathrooms                       0.000000e+00  1.000000e+00  1.000000e+00
# Bedrooms                        0.000000e+00  1.000000e+00  1.000000e+00
# Beds                            1.000000e+00  1.000000e+00  2.000000e+00
# Square Feet                     0.000000e+00  0.000000e+00  8.600000e+01
# Price                           9.000000e+00  3.000000e+01  5.200000e+01
# Weekly Price                    7.000000e+01  2.072500e+02  3.500000e+02
# Monthly Price                   2.500000e+02  7.000000e+02  1.200000e+03
# Security Deposit                7.000000e+01  1.000000e+02  1.500000e+02
# Cleaning Fee                    4.000000e+00  1.500000e+01  2.500000e+01
# Guests Included                 1.000000e+00  1.000000e+00  1.000000e+00
# Extra People                    0.000000e+00  0.000000e+00  0.000000e+00
# Minimum Nights                  1.000000e+00  1.000000e+00  2.000000e+00
# Maximum Nights                  1.000000e+00  3.650000e+02  1.125000e+03
# Has Availability                         NaN           NaN           NaN
# Availability 30                 0.000000e+00  0.000000e+00  6.000000e+00
# Availability 60                 0.000000e+00  5.000000e+00  2.000000e+01
# Availability 90                 0.000000e+00  1.200000e+01  3.800000e+01
# Availability 365                0.000000e+00  8.300000e+01  2.470000e+02
# Number of Reviews               0.000000e+00  1.000000e+00  7.000000e+00
# Review Scores Rating            2.000000e+01  8.900000e+01  9.400000e+01
# Review Scores Accuracy          2.000000e+00  9.000000e+00  1.000000e+01
# Review Scores Cleanliness       2.000000e+00  9.000000e+00  1.000000e+01
# Review Scores Checkin           2.000000e+00  9.000000e+00  1.000000e+01
# Review Scores Communication     2.000000e+00  9.000000e+00  1.000000e+01
# Review Scores Location          2.000000e+00  9.000000e+00  1.000000e+01
# Review Scores Value             2.000000e+00  9.000000e+00  9.000000e+00
# Jurisdiction Names                       NaN           NaN           NaN
# Calculated host listings count  1.000000e+00  1.000000e+00  2.000000e+00
# Reviews per Month               2.000000e-02  4.800000e-01  1.260000e+00
#
#                                          75%           max
# ID                              1.537016e+07  1.810918e+07
# Scrape ID                       2.017041e+13  2.017041e+13
# Host ID                         5.705880e+07  1.247534e+08
# Host Response Rate              1.000000e+02  1.000000e+02
# Host Acceptance Rate                     NaN           NaN
# Host Listings Count             5.000000e+00  2.650000e+02
# Host Total Listings Count       5.000000e+00  2.650000e+02
# Latitude                        4.042779e+01  4.056274e+01
# Longitude                      -3.693819e+00 -3.573613e+00
# Accommodates                    4.000000e+00  1.600000e+01
# Bathrooms                       1.000000e+00  8.000000e+00
# Bedrooms                        2.000000e+00  1.000000e+01
# Beds                            2.000000e+00  1.600000e+01
# Square Feet                     5.920000e+02  5.167000e+03
# Price                           8.000000e+01  8.750000e+02
# Weekly Price                    4.900000e+02  9.990000e+02
# Monthly Price                   1.658000e+03  2.500000e+04
# Security Deposit                2.000000e+02  9.900000e+02
# Cleaning Fee                    3.500000e+01  5.000000e+02
# Guests Included                 2.000000e+00  1.500000e+01
# Extra People                    1.400000e+01  2.740000e+02
# Minimum Nights                  3.000000e+00  1.125000e+03
# Maximum Nights                  1.125000e+03  1.000000e+06
# Has Availability                         NaN           NaN
# Availability 30                 1.300000e+01  3.000000e+01
# Availability 60                 3.800000e+01  6.000000e+01
# Availability 90                 6.500000e+01  9.000000e+01
# Availability 365                3.210000e+02  3.650000e+02
# Number of Reviews               2.800000e+01  4.460000e+02
# Review Scores Rating            9.800000e+01  1.000000e+02
# Review Scores Accuracy          1.000000e+01  1.000000e+01
# Review Scores Cleanliness       1.000000e+01  1.000000e+01
# Review Scores Checkin           1.000000e+01  1.000000e+01
# Review Scores Communication     1.000000e+01  1.000000e+01
# Review Scores Location          1.000000e+01  1.000000e+01
# Review Scores Value             1.000000e+01  1.000000e+01
# Jurisdiction Names                       NaN           NaN
# Calculated host listings count  4.000000e+00  1.450000e+02
# Reviews per Month               2.890000e+00  1.390000e+01

# %%
#Comprobamos los valores nulos de cada columna
pd.options.display.max_rows=None 
df.isnull().sum()
# Out:
# ID                                    0
# Listing Url                           0
# Scrape ID                             0
# Last Scraped                          0
# Name                                  0
# Summary                             394
# Space                              2865
# Description                           3
# Experiences Offered                   0
# Neighborhood Overview              3976
# Notes                              6570
# Transit                            4019
# Access                             4576
# Interaction                        4617
# House Rules                        3704
# Thumbnail Url                      2009
# Medium Url                         2009
# Picture Url                          15
# XL Picture Url                     2009
# Host ID                               0
# Host URL                              0
# Host Name                             3
# Host Since                            3
# Host Location                        36
# Host About                         4007
# Host Response Time                 1318
# Host Response Rate                 1318
# Host Acceptance Rate              10596
# Host Thumbnail Url                    3
# Host Picture Url                      3
# Host Neighbourhood                 2607
# Host Listings Count                   3
# Host Total Listings Count             3
# Host Verifications                    5
# Street                                0
# Neighbourhood                      3583
# Neighbourhood Cleansed                0
# Neighbourhood Group Cleansed          0
# City                                  0
# State                                35
# Zipcode                             347
# Market                               43
# Smart Location                        0
# Country Code                          0
# Country                               0
# Latitude                              0
# Longitude                             0
# Property Type                         0
# Room Type                             0
# Accommodates                          0
# Bathrooms                            37
# Bedrooms                             16
# Beds                                 38
# Bed Type                              0
# Amenities                            91
# Square Feet                       10172
# Price                                 8
# Weekly Price                       7916
# Monthly Price                      7951
# Security Deposit                   6117
# Cleaning Fee                       4355
# Guests Included                       0
# Extra People                          0
# Minimum Nights                        0
# Maximum Nights                        0
# Calendar Updated                      0
# Has Availability                  10596
# Availability 30                       0
# Availability 60                       0
# Availability 90                       0
# Availability 365                      0
# Calendar last Scraped                 0
# Number of Reviews                     0
# First Review                       2196
# Last Review                        2197
# Review Scores Rating               2296
# Review Scores Accuracy             2309
# Review Scores Cleanliness          2302
# Review Scores Checkin              2312
# Review Scores Communication        2302
# Review Scores Location             2313
# Review Scores Value                2314
# License                           10391
# Jurisdiction Names                10596
# Cancellation Policy                   0
# Calculated host listings count        0
# Reviews per Month                  2196
# Geolocation                           0
# Features                              0
# dtype: int64

# %% [markdown]
# **Tras realizar una primera visualización del tipo de columnas que tiene el DF, se observa que existen muchas columnas que en principio no serían relevantes para el análisis que vamos a realizar o que unicamente contiene NA o tienen muy pocas filas con dicha información como puede ser el precio semanal o mensual o que contienen información redundante. En este punto podriamos valorar la posibilidad de categorizar alguna de las características que nos proporciona la columna Ammenities.**
#
# **Vamos a eliminar las columnas que en base a lo anterior son irrelevantes:**

# %%
#Creamos una variable que almacene las columnas que queremos eliminar y realizamos la llamada a la función que elimina columnas para llevar a cabo 
#la primera transformación del DF de train
colums_to_remove = ['ID','Host ID','Listing Url','Scrape ID','Last Scraped','Neighbourhood Cleansed','Name','Summary','Space','Description','Experiences Offered','Neighborhood Overview','Notes','Transit',
                    'Access','Interaction','House Rules','Thumbnail Url','Medium Url','Picture Url','XL Picture Url','Host URL','Host Name','Host About', 'Host Response Rate',
                    'Calculated host listings count','Host Thumbnail Url','Host Picture Url','Host Verifications','Features','Square Feet','Host Acceptance Rate','Has Availability',
                    'Jurisdiction Names','Latitude','Longitude','Weekly Price','Monthly Price','Country','License','Geolocation','Calendar last Scraped','Calendar Updated','Square Feet',
                    'Host Neighbourhood','Host Response Time','Reviews per Month','First Review','Last Review','Review Scores Rating','Review Scores Accuracy','Review Scores Cleanliness',
                    'Review Scores Checkin','Review Scores Communication','Review Scores Location','Review Scores Value','Reviews per Month','Neighbourhood','Market','State','Zipcode',
                    'Smart Location','Country Code','Host Location','Host Listings Count','Host Total Listings Count','Host Since','City','Street','Guests Included','Number of Reviews']
df = first_trasnformation(df,colums_to_remove)

# %%
df.describe().T
# Out:
#                     count        mean          std   min    25%     50%  \
# Accommodates      10596.0    3.190260     2.000907   1.0    2.0     2.0
# Bathrooms         10559.0    1.251776     0.602483   0.0    1.0     1.0
# Bedrooms          10580.0    1.291210     0.822789   0.0    1.0     1.0
# Beds              10558.0    1.991760     1.527565   1.0    1.0     2.0
# Price             10588.0   66.068946    56.414585   9.0   30.0    52.0
# Security Deposit   4479.0  183.243804   108.810750  70.0  100.0   150.0
# Cleaning Fee       6241.0   29.492069    25.720340   4.0   15.0    25.0
# Extra People      10596.0    7.413364    10.530548   0.0    0.0     0.0
# Minimum Nights    10596.0    3.001038    13.300005   1.0    1.0     2.0
# Maximum Nights    10596.0  977.748773  9914.065304   1.0  365.0  1125.0
# Availability 30   10596.0    8.744054     9.090992   0.0    0.0     6.0
# Availability 60   10596.0   22.929690    19.536562   0.0    5.0    20.0
# Availability 90   10596.0   40.095319    29.422056   0.0   12.0    38.0
# Availability 365  10596.0  205.136844   127.375124   0.0   83.0   247.0
#
#                      75%        max
# Accommodates         4.0       16.0
# Bathrooms            1.0        8.0
# Bedrooms             2.0       10.0
# Beds                 2.0       16.0
# Price               80.0      875.0
# Security Deposit   200.0      990.0
# Cleaning Fee        35.0      500.0
# Extra People        14.0      274.0
# Minimum Nights       3.0     1125.0
# Maximum Nights    1125.0  1000000.0
# Availability 30     13.0       30.0
# Availability 60     38.0       60.0
# Availability 90     65.0       90.0
# Availability 365   321.0      365.0

# %%
df.isnull().sum()
# Out:
# Neighbourhood Group Cleansed       0
# Property Type                      0
# Room Type                          0
# Accommodates                       0
# Bathrooms                         37
# Bedrooms                          16
# Beds                              38
# Bed Type                           0
# Amenities                         91
# Price                              8
# Security Deposit                6117
# Cleaning Fee                    4355
# Extra People                       0
# Minimum Nights                     0
# Maximum Nights                     0
# Availability 30                    0
# Availability 60                    0
# Availability 90                    0
# Availability 365                   0
# Cancellation Policy                0
# dtype: int64

# %% [markdown]
# **Análisis de variables numéricas:**

# %% [markdown]
# En base a las celdas anteriores vemos que existen dimensiones con posibles outliersy muchas que tienen valores NA por lo que vamos a graficar los datos en busca de anomalias.
# En la siguiente celda generamos los histogramas de las variables numérica.

# %%
create_hist(df)

# %% [markdown]
# En la siguiente celda realizamos las gráficas scatter.

# %%
create_scatter(df)

# %% [markdown]
# Calculamos la matriz de correlación.

# %%
corr_matrix(df)

# %% [markdown]
# Tras visualizar los scatterplot observamos que hay variables que a priori se relacionan bastante con el precio, como pueden ser Accommodates, Bathrooms, Bedrooms, beds, Cleaning Fee y Extra People. En las siguientes celdas vamos a analizar un poco más a fondo las dos últimas dimensiones mencionadas. Además también observamos que 'Minimum Nights' y 'Maximum Nights' en principio aportarían poco al modelo por lo tanto las vamos a eliminar. Además vamos a eliminar las dimensiones de Availability por que tampoco parece que tengan una fuerte relación con el precio y están muy correladas entre si

# %%
create_scatter(df, columns=['Availability 60'], y =['Availability 30'])

# %%
col_delete = ['Minimum Nights', 'Maximum Nights', 'Availability 30', 'Availability 60', 'Availability 90', 'Availability 365' ]
df = first_trasnformation(df,col_delete)

# %% [markdown]
# **A pesar de que entiendo que no es del todo correcto vamos asumir que los alojamientos que no tienen asignado un valor de Cleaning Fee es por que no se cobra dicha tarifa, por lo que los pondremos a cero**

# %%
#rellenamos los Cleaning Fee Na con ceros
df['Cleaning Fee'] = df['Cleaning Fee'].fillna(0)

# %% [markdown]
# El Security Deposit, lo trasnformaremos a categórico donde 0 es que no se requiere depósito y 1 que si. Por otro lado para saber si el alojamiento tiene aire acondicionado y calefacción creamos dos columnas en donde indica (SI/NO). y por último convierte a dummies las 3 columnas trasnformadas para ello usaremos la funcion second_transformation.

# %%
#llamamos a la función second_transformation para realizar lo indicado
df = second_transformation(df)

# %% [markdown]
# Analizamos la variable Claning Fee en las que se observa valores que pueden ser posibles outliers

# %%
print('Resumen de la variable:')
print(df['Cleaning Fee'].describe())
print('-----------------------------------------------------------------------------')
filtered = (df['Cleaning Fee'][df['Cleaning Fee']>100])
print(f'Existen {filtered.shape[0]} valores de Cleaning Fee superiores a 100 euros, distribuidos de la siguiente manera:')
print(filtered.value_counts())
print('-----------------------------------------------------------------------------')
df[df['Cleaning Fee']>100].head(15)
# Out:
# Resumen de la variable:
# count    10596.000000
# mean        17.370706
# std         24.498831
# min          0.000000
# 25%          0.000000
# 50%         10.000000
# 75%         30.000000
# max        500.000000
# Name: Cleaning Fee, dtype: float64
# -----------------------------------------------------------------------------
# Existen 81 valores de Cleaning Fee superiores a 100 euros, distribuidos de la siguiente manera:
# 200.0    15
# 250.0    11
# 140.0    11
# 150.0     9
# 120.0     9
# 103.0     7
# 160.0     5
# 300.0     4
# 180.0     2
# 110.0     2
# 500.0     1
# 350.0     1
# 115.0     1
# 375.0     1
# 105.0     1
# 174.0     1
# Name: Cleaning Fee, dtype: int64
# -----------------------------------------------------------------------------
#      Neighbourhood Group Cleansed Property Type        Room Type  \
# 8                       Salamanca     Apartment  Entire home/apt
# 134                        Centro     Apartment  Entire home/apt
# 206                      Chamberí     Apartment  Entire home/apt
# 434                     Salamanca     Apartment  Entire home/apt
# 838                        Centro     Apartment  Entire home/apt
# 890                     Hortaleza         House  Entire home/apt
# 1329                     Chamberí     Apartment  Entire home/apt
# 1376                    Salamanca     Apartment  Entire home/apt
# 1620                     Chamberí     Apartment  Entire home/apt
# 1735                       Tetuán     Apartment  Entire home/apt
# 1885                    Salamanca     Apartment  Entire home/apt
# 1960            Moncloa - Aravaca         House  Entire home/apt
# 1984                       Retiro     Apartment  Entire home/apt
# 2015                       Centro     Apartment  Entire home/apt
# 2068                    Salamanca     Apartment  Entire home/apt
#
#       Accommodates  Bathrooms  Bedrooms  Beds  Bed Type  Price  Cleaning Fee  \
# 8                6        3.0       3.0   5.0  Real Bed  465.0         300.0
# 134             16        6.0       6.0  16.0  Real Bed  400.0         150.0
# 206              8        3.5       4.0   6.0  Real Bed  280.0         180.0
# 434              4        2.0       2.0   4.0  Real Bed  310.0         250.0
# 838             16        4.5       7.0   9.0  Real Bed  399.0         110.0
# 890             10        3.5       4.0   5.0  Real Bed  350.0         150.0
# 1329             5        2.0       3.0   4.0  Real Bed  150.0         140.0
# 1376             9        2.0       3.0   4.0  Real Bed  190.0         120.0
# 1620             6        2.5       3.0   5.0  Real Bed  220.0         140.0
# 1735             4        1.5       2.0   4.0  Real Bed  207.0         250.0
# 1885             2        1.0       1.0   1.0  Real Bed  210.0         200.0
# 1960            14        6.0       7.0   9.0  Real Bed  750.0         500.0
# 1984             7        4.0       4.0   5.0  Real Bed  536.0         103.0
# 2015             6        3.0       3.0   3.0  Real Bed  350.0         120.0
# 2068             2        1.0       1.0   2.0  Real Bed  160.0         200.0
#
#       Extra People Cancellation Policy  A/C_NO  A/C_SI  Heat_NO  Heat_SI  \
# 8                0              strict       0       1        0        1
# 134              0              strict       0       1        0        1
# 206              0              strict       0       1        0        1
# 434              0              strict       0       1        0        1
# 838             15              strict       1       0        0        1
# 890             50              strict       0       1        0        1
# 1329             0              strict       0       1        0        1
# 1376            30              strict       0       1        0        1
# 1620             0              strict       0       1        0        1
# 1735             0              strict       0       1        0        1
# 1885             0              strict       0       1        0        1
# 1960             0              strict       0       1        0        1
# 1984             0              strict       0       1        0        1
# 2015             0              strict       1       0        0        1
# 2068             0              strict       0       1        0        1
#
#       Sec_Dep_NO  Sec_Dep_SI
# 8              1           0
# 134            0           1
# 206            0           1
# 434            1           0
# 838            0           1
# 890            0           1
# 1329           0           1
# 1376           1           0
# 1620           0           1
# 1735           1           0
# 1885           1           0
# 1960           1           0
# 1984           1           0
# 2015           0           1
# 2068           0           1

# %% [markdown]
# Vamos a optar por la eliminación de la variable Cleaning Fee, ya que existen bastantes valores elevados y que analizando un poco el dataser filtrado
# parece que éste importe tiene bastante relación con el mínimo de noches de alojamiento.

# %%
col_delete = ['Cleaning Fee']
df = first_trasnformation(df,col_delete)

# %% [markdown]
# Analizamos la variable Extra People

# %%
print('Resumen de la variable:')
print(df['Extra People'].describe())
print('-----------------------------------------------------------------------------')
filtered = (df['Extra People'][df['Extra People']>60])
print(f'Existen {filtered.shape[0]} valores de Cleaning Fee superiores a 100 euros, distribuidos de la siguiente manera:')
print(filtered.value_counts())
print('-----------------------------------------------------------------------------')
df[df['Extra People']>30].head(15)
# Out:
# Resumen de la variable:
# count    10596.000000
# mean         7.413364
# std         10.530548
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         14.000000
# max        274.000000
# Name: Extra People, dtype: float64
# -----------------------------------------------------------------------------
# Existen 14 valores de Cleaning Fee superiores a 100 euros, distribuidos de la siguiente manera:
# 75     3
# 250    2
# 100    2
# 70     2
# 80     1
# 65     1
# 274    1
# 150    1
# 271    1
# Name: Extra People, dtype: int64
# -----------------------------------------------------------------------------
#      Neighbourhood Group Cleansed    Property Type        Room Type  \
# 378                        Centro             Loft  Entire home/apt
# 459                    Arganzuela      Condominium     Private room
# 714                        Retiro        Apartment  Entire home/apt
# 819                      Chamberí        Apartment  Entire home/apt
# 890                     Hortaleza            House  Entire home/apt
# 951                        Centro        Apartment  Entire home/apt
# 953                        Centro        Apartment  Entire home/apt
# 989                        Centro            House  Entire home/apt
# 1161                     Chamberí  Bed & Breakfast     Private room
# 1222                       Centro        Apartment  Entire home/apt
# 1239                       Centro        Apartment  Entire home/apt
# 1277                     Chamberí  Bed & Breakfast     Private room
# 1338                Ciudad Lineal      Condominium     Private room
# 1454                       Centro        Apartment  Entire home/apt
# 1466                       Centro        Apartment  Entire home/apt
#
#       Accommodates  Bathrooms  Bedrooms  Beds       Bed Type  Price  \
# 378              2        1.0       1.0   1.0       Real Bed   95.0
# 459              2        1.0       1.0   2.0       Real Bed   30.0
# 714              2        1.0       1.0   1.0       Real Bed   70.0
# 819              2        1.0       1.0   1.0       Real Bed   75.0
# 890             10        3.5       4.0   5.0       Real Bed  350.0
# 951              2        1.0       1.0   1.0       Real Bed   50.0
# 953              3        1.0       0.0   2.0  Pull-out Sofa  125.0
# 989              9        3.0       3.0   7.0       Real Bed  146.0
# 1161             2        6.0       1.0   1.0       Real Bed   45.0
# 1222             3        1.0       1.0   1.0       Real Bed   80.0
# 1239             5        1.0       2.0   5.0       Real Bed  150.0
# 1277             1        6.0       1.0   1.0       Real Bed   45.0
# 1338             3        1.0       1.0   3.0       Real Bed   40.0
# 1454             2        1.0       1.0   1.0       Real Bed   65.0
# 1466             2        1.0       1.0   2.0       Real Bed   60.0
#
#       Extra People Cancellation Policy  A/C_NO  A/C_SI  Heat_NO  Heat_SI  \
# 378             50            flexible       0       1        0        1
# 459             50            moderate       1       0        0        1
# 714             40              strict       1       0        0        1
# 819             45              strict       0       1        0        1
# 890             50              strict       0       1        0        1
# 951             50            flexible       1       0        0        1
# 953             35              strict       0       1        0        1
# 989             39            flexible       0       1        0        1
# 1161            45              strict       0       1        0        1
# 1222            45              strict       1       0        0        1
# 1239            40            flexible       1       0        1        0
# 1277            45              strict       0       1        0        1
# 1338            36            flexible       0       1        0        1
# 1454            50            flexible       1       0        0        1
# 1466            40            moderate       0       1        0        1
#
#       Sec_Dep_NO  Sec_Dep_SI
# 378            0           1
# 459            1           0
# 714            0           1
# 819            0           1
# 890            0           1
# 951            0           1
# 953            0           1
# 989            1           0
# 1161           0           1
# 1222           0           1
# 1239           0           1
# 1277           0           1
# 1338           0           1
# 1454           0           1
# 1466           0           1

# %% [markdown]
# Por último vamos a eliminar tambiés esta variable por que apriori no parece muy fiable, ya que tiene valores de extrapeople muy altos para alojamientos
# muy pequeños

# %%
col_delete = ['Extra People']
df = first_trasnformation(df,col_delete)

# %%
pd.options.display.max_rows=100
df.dtypes
# Out:
# Neighbourhood Group Cleansed     object
# Property Type                    object
# Room Type                        object
# Accommodates                      int64
# Bathrooms                       float64
# Bedrooms                        float64
# Beds                            float64
# Bed Type                         object
# Price                           float64
# Cancellation Policy              object
# A/C_NO                            uint8
# A/C_SI                            uint8
# Heat_NO                           uint8
# Heat_SI                           uint8
# Sec_Dep_NO                        uint8
# Sec_Dep_SI                        uint8
# dtype: object

# %% [markdown]
# **Variables categóricas**

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#        Neighbourhood Group Cleansed Property Type        Room Type  Bed Type  \
# count                         10596         10596            10596     10596
# unique                           21            21                3         5
# top                          Centro     Apartment  Entire home/apt  Real Bed
# freq                           5418          8717             6324     10378
#
#        Cancellation Policy
# count                10596
# unique                   5
# top                 strict
# freq                  4004

# %%
create_dist_categ(df)

# %%
df['Cancellation Policy'].value_counts()
# Out:
# strict             4004
# flexible           3413
# moderate           3176
# super_strict_60       2
# super_strict_30       1
# Name: Cancellation Policy, dtype: int64

# %% [markdown]
# Vamos a reagrupar los niveles reagrupando los que contienen strict en strict

# %%
list_index_canc_Pol = df['Cancellation Policy'].value_counts().index[0:3] 
#Usamos la unción regroup_values para cambiar los nombres de los niveles 
regroup_values(df,'Cancellation Policy',list_index_canc_Pol, new_value='strict')

# %%
#Comprobamos si se hizo correctamente el reagrupamiento
df['Cancellation Policy'].value_counts()
# Out:
# strict      4007
# flexible    3413
# moderate    3176
# Name: Cancellation Policy, dtype: int64

# %%
df['Property Type'].value_counts()
# Out:
# Apartment             8717
# House                  784
# Condominium            285
# Bed & Breakfast        283
# Loft                   218
# Other                  178
# Guesthouse              33
# Dorm                    33
# Chalet                  17
# Hostel                  12
# Serviced apartment      11
# Townhouse                7
# Boutique hotel           4
# Villa                    3
# Guest suite              3
# Earth House              3
# Timeshare                1
# Bungalow                 1
# Boat                     1
# Tent                     1
# Casa particular          1
# Name: Property Type, dtype: int64

# %% [markdown]
# Vamos a reagrupar los niveles manteniendo hasta loft y el resto los reagruparemos en Other

# %%
list_index_prop_type = df['Property Type'].value_counts().index[0:5] #Creamos una lista con los valores que mantendremos
#Usamos la unción regroup_values para cambiar los nombres de los niveles 
regroup_values(df,'Property Type',list_index_prop_type)

# %%
#Comprobamos el reagrupapiemnto
df['Property Type'].value_counts()
# Out:
# Apartment          8717
# House               784
# Other               309
# Condominium         285
# Bed & Breakfast     283
# Loft                218
# Name: Property Type, dtype: int64

# %% [markdown]
# Realizamos lo mismo con Bed Type

# %%
df['Bed Type'].value_counts()
# Out:
# Real Bed         10378
# Pull-out Sofa      177
# Futon               28
# Couch                9
# Airbed               4
# Name: Bed Type, dtype: int64

# %%
list_index_bed_type = df['Bed Type'].value_counts().index[0:2] 
#Usamos la unción regroup_values para cambiar los nombres de los niveles 
regroup_values(df,'Bed Type',list_index_bed_type)

# %%
df['Bed Type'].value_counts()
# Out:
# Real Bed         10378
# Pull-out Sofa      177
# Other               41
# Name: Bed Type, dtype: int64

# %% [markdown]
# Realizamos los boxplots para ver como se distribuye ahora el precio por categorias

# %%
create_boxplot(df)

# %% [markdown]
# Ahora vamos a realizar la trasnformación de las variables ['Neighbourhood_Group_Cleansed','Property_Type','Room_Type', 'Bed_Type', 'Cancellation_Policy'],  mediante MeanEncoder de la libreria
# Feature_engine

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10596 entries, 0 to 10595
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neighbourhood Group Cleansed  10596 non-null  object
#  1   Property Type                 10596 non-null  object
#  2   Room Type                     10596 non-null  object
#  3   Accommodates                  10596 non-null  int64
#  4   Bathrooms                     10559 non-null  float64
#  5   Bedrooms                      10580 non-null  float64
#  6   Beds                          10558 non-null  float64
#  7   Bed Type                      10596 non-null  object
#  8   Price                         10588 non-null  float64
#  9   Cancellation Policy           10596 non-null  object
#  10  A/C_NO                        10596 non-null  uint8
#  11  A/C_SI                        10596 non-null  uint8
#  12  Heat_NO                       10596 non-null  uint8
#  13  Heat_SI                       10596 non-null  uint8
#  14  Sec_Dep_NO                    10596 non-null  uint8
#  15  Sec_Dep_SI                    10596 non-null  uint8
# dtypes: float64(4), int64(1), object(5), uint8(6)
# memory usage: 890.0+ KB

# %% [markdown]
# primero generamos las variables x_train e y_train

# %%
new_index = ['Neighbourhood Group Cleansed',
       'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Beds', 'Bed Type', 'Cancellation Policy',
       'A/C_NO', 'A/C_SI', 'Heat_NO', 'Heat_SI', 'Sec_Dep_NO', 'Sec_Dep_SI','Price']
df = df.dropna()
df =  df.reindex(columns = new_index)
#modificamos el nombre de las columnas para que no haya espacios si no la función MeanEncoder nos daría problemas
df.columns = ['Neighbourhood_Group_Cleansed',
       'Property_Type', 'Room_Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Beds', 'Bed_Type', 'Cancellation_Policy',
       'A/C_NO', 'A/C_SI', 'Heat_NO', 'Heat_SI', 'Sec_Dep_NO', 'Sec_Dep_SI','Price']
feature_names = df.columns[:-1]
y_train = df['Price']                   # nos quedamos con la última columna, price
X_train = df.drop('Price',axis =1)      # nos quedamos con el resto

# %%
main_encoder_categorical = MeanEncoder(variables=['Neighbourhood_Group_Cleansed','Property_Type','Room_Type', 'Bed_Type', 'Cancellation_Policy'])

# %%
main_encoder_categorical.fit(X_train, y_train)
# Out:
# MeanEncoder(variables=['Neighbourhood_Group_Cleansed', 'Property_Type',
#                        'Room_Type', 'Bed_Type', 'Cancellation_Policy'])

# %%
main_encoder_categorical.encoder_dict_
# Out:
# {'Neighbourhood_Group_Cleansed': {'Arganzuela': 46.306946688206786,
#   'Barajas': 56.854838709677416,
#   'Carabanchel': 39.157706093189965,
#   'Centro': 73.19031719532555,
#   'Chamartín': 72.43165467625899,
#   'Chamberí': 73.02325581395348,
#   'Ciudad Lineal': 43.81856540084388,
#   'Fuencarral - El Pardo': 50.578512396694215,
#   'Hortaleza': 53.8,
#   'Latina': 34.320388349514566,
#   'Moncloa - Aravaca': 67.6,
#   'Moratalaz': 36.016949152542374,
#   'Puente de Vallecas': 37.27485380116959,
#   'Retiro': 70.28169014084507,
#   'Salamanca': 84.37031700288185,
#   'San Blas - Canillejas': 36.95652173913044,
#   'Tetuán': 52.93646408839779,
#   'Usera': 39.78151260504202,
#   'Vicálvaro': 36.46153846153846,
#   'Villa de Vallecas': 44.743589743589745,
#   'Villaverde': 32.546875},
#  'Property_Type': {'Apartment': 67.97958712951217,
#   'Bed & Breakfast': 38.135714285714286,
#   'Condominium': 61.540636042402824,
#   'House': 57.316946959896505,
#   'Loft': 71.17511520737327,
#   'Other': 60.71854304635762},
#  'Room_Type': {'Entire home/apt': 87.60320736741822,
#   'Private room': 34.192487110238154,
#   'Shared room': 29.948387096774194},
#  'Bed_Type': {'Other': 46.951219512195124,
#   'Pull-out Sofa': 57.04545454545455,
#   'Real Bed': 66.31758657483752},
#  'Cancellation_Policy': {'flexible': 56.997037914691944,
#   'moderate': 62.440265486725664,
#   'strict': 76.68088309081786}}

# %%
X_train = main_encoder_categorical.transform(X_train)

# %%
X_train
# Out:
#        Neighbourhood_Group_Cleansed  Property_Type  Room_Type  Accommodates  \
# 0                         73.190317      67.979587  87.603207             4
# 1                         73.190317      67.979587  87.603207             7
# 2                         73.190317      71.175115  87.603207             4
# 3                         73.190317      67.979587  34.192487             2
# 4                         53.800000      67.979587  34.192487             1
# ...                             ...            ...        ...           ...
# 10590                     73.190317      67.979587  29.948387             1
# 10591                     52.936464      67.979587  87.603207             6
# 10592                     73.190317      67.979587  87.603207             4
# 10593                     73.190317      67.979587  87.603207             6
# 10594                     73.190317      67.979587  87.603207             5
#
#        Bathrooms  Bedrooms  Beds   Bed_Type  Cancellation_Policy  A/C_NO  \
# 0            1.0       1.0   2.0  66.317587            76.680883       0
# 1            2.0       3.0   3.0  66.317587            76.680883       0
# 2            1.0       1.0   2.0  66.317587            76.680883       1
# 3            0.5       1.0   1.0  66.317587            76.680883       1
# 4            1.0       1.0   1.0  66.317587            62.440265       1
# ...          ...       ...   ...        ...                  ...     ...
# 10590        1.0       1.0   1.0  66.317587            56.997038       1
# 10591        1.5       3.0   4.0  66.317587            56.997038       0
# 10592        1.0       2.0   3.0  66.317587            56.997038       1
# 10593        1.0       1.0   4.0  66.317587            62.440265       0
# 10594        2.0       2.0   3.0  66.317587            76.680883       1
#
#        A/C_SI  Heat_NO  Heat_SI  Sec_Dep_NO  Sec_Dep_SI
# 0           1        0        1           1           0
# 1           1        0        1           0           1
# 2           0        0        1           0           1
# 3           0        1        0           1           0
# 4           0        0        1           1           0
# ...       ...      ...      ...         ...         ...
# 10590       0        1        0           1           0
# 10591       1        0        1           1           0
# 10592       0        0        1           1           0
# 10593       1        0        1           1           0
# 10594       0        0        1           0           1
#
# [10526 rows x 15 columns]

# %% [markdown]
# **Volvemos a visualizar los datos en graficas**

# %%
create_boxplot(df)

# %%
X_train
# Out:
#        Neighbourhood_Group_Cleansed  Property_Type  Room_Type  Accommodates  \
# 0                         73.190317      67.979587  87.603207             4
# 1                         73.190317      67.979587  87.603207             7
# 2                         73.190317      71.175115  87.603207             4
# 3                         73.190317      67.979587  34.192487             2
# 4                         53.800000      67.979587  34.192487             1
# ...                             ...            ...        ...           ...
# 10590                     73.190317      67.979587  29.948387             1
# 10591                     52.936464      67.979587  87.603207             6
# 10592                     73.190317      67.979587  87.603207             4
# 10593                     73.190317      67.979587  87.603207             6
# 10594                     73.190317      67.979587  87.603207             5
#
#        Bathrooms  Bedrooms  Beds   Bed_Type  Cancellation_Policy  A/C_NO  \
# 0            1.0       1.0   2.0  66.317587            76.680883       0
# 1            2.0       3.0   3.0  66.317587            76.680883       0
# 2            1.0       1.0   2.0  66.317587            76.680883       1
# 3            0.5       1.0   1.0  66.317587            76.680883       1
# 4            1.0       1.0   1.0  66.317587            62.440265       1
# ...          ...       ...   ...        ...                  ...     ...
# 10590        1.0       1.0   1.0  66.317587            56.997038       1
# 10591        1.5       3.0   4.0  66.317587            56.997038       0
# 10592        1.0       2.0   3.0  66.317587            56.997038       1
# 10593        1.0       1.0   4.0  66.317587            62.440265       0
# 10594        2.0       2.0   3.0  66.317587            76.680883       1
#
#        A/C_SI  Heat_NO  Heat_SI  Sec_Dep_NO  Sec_Dep_SI
# 0           1        0        1           1           0
# 1           1        0        1           0           1
# 2           0        0        1           0           1
# 3           0        1        0           1           0
# 4           0        0        1           1           0
# ...       ...      ...      ...         ...         ...
# 10590       0        1        0           1           0
# 10591       1        0        1           1           0
# 10592       0        0        1           1           0
# 10593       1        0        1           1           0
# 10594       0        0        1           0           1
#
# [10526 rows x 15 columns]

# %%
create_scatter(df)

# %%
corr_matrix(df)

# %% [markdown]
# En base a la matriz de correlación observamos que las dimensiones Beds y Accommodates están muy correladas como es obvio. Aun asi no llega al humbral marcado de 0.9 asique mantendremos las dos

# %% [markdown]
# **Estandarizamos los datos**

# %% [markdown]
# Vamos a modificar el indice de las columnas para pasar la variable buscada a la última columna

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %%
X_train
# Out:
# array([[ 0.51269579,  0.33827653,  0.81919203, ...,  0.29884735,
#          0.85746465, -0.85746465],
#        [ 0.51269579,  0.33827653,  0.81919203, ...,  0.29884735,
#         -1.16622883,  1.16622883],
#        [ 0.51269579,  0.90947312,  0.81919203, ...,  0.29884735,
#         -1.16622883,  1.16622883],
#        ...,
#        [ 0.51269579,  0.33827653,  0.81919203, ...,  0.29884735,
#          0.85746465, -0.85746465],
#        [ 0.51269579,  0.33827653,  0.81919203, ...,  0.29884735,
#          0.85746465, -0.85746465],
#        [ 0.51269579,  0.33827653,  0.81919203, ...,  0.29884735,
#         -1.16622883,  1.16622883]])

# %% [markdown]
# **Hemos realizado el análisis y la transformación del dataset, para ello hemos creado varias funciones que realizan todas las trasnforaciones paso a paso y que
# usaremos para realizar la trasnformación del grupo de test. El siguiente código realiza la trasnformación al df test**

# %%
#Cargamos el df test
df_test = pd.read_csv('dataframes/test.csv', sep=';', decimal='.')

#Variables necesarias para la trasnformación:
colums_to_remove_test = ['ID','Host ID','Listing Url','Scrape ID','Last Scraped','Name','Summary','Space','Description','Experiences Offered','Neighborhood Overview','Notes','Transit',
                    'Access','Interaction','House Rules','Thumbnail Url','Medium Url','Picture Url','XL Picture Url','Host URL','Host Name','Host About', 'Host Response Rate',
                    'Calculated host listings count','Host Thumbnail Url','Host Picture Url','Host Verifications','Features','Square Feet','Host Acceptance Rate','Has Availability',
                    'Jurisdiction Names','Latitude','Longitude','Weekly Price','Monthly Price','Country','License','Geolocation','Calendar last Scraped','Calendar Updated','Square Feet',
                    'Host Neighbourhood','Host Response Time','Reviews per Month','First Review','Last Review','Review Scores Rating','Review Scores Accuracy','Review Scores Cleanliness',
                    'Review Scores Checkin','Review Scores Communication','Review Scores Location','Review Scores Value','Reviews per Month','Neighbourhood','Market','State','Zipcode',
                    'Smart Location','Country Code','Host Location','Host Listings Count','Host Total Listings Count','Host Since','City','Street','Guests Included','Minimum Nights',
                    'Maximum Nights','Extra People','Cleaning Fee','Availability 30', 'Availability 60', 'Availability 90', 'Availability 365','Neighbourhood Cleansed','Number of Reviews']
new_index = ['Neighbourhood Cleansed', 'Neighbourhood Group Cleansed',
       'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Beds', 'Bed Type', 'Cancellation Policy',
       'A/C_NO', 'A/C_SI', 'Heat_NO', 'Heat_SI', 'Sec_Dep_NO', 'Sec_Dep_SI','Price'] #Indice final                   
#Realizamos las trasnformaciones
df_test = first_trasnformation(df_test,colums_to_remove_test)
df_test = second_transformation(df_test)
list_index_prop_type = df_test['Property Type'].value_counts().index[0:5]    #Indice para realizar la agrupación de property type   
list_index_canc_Pol = df_test['Cancellation Policy'].value_counts().index[0:3] #Indice para realizar la agrupación de Cancelation polcity  
list_index_bed_type = df_test['Bed Type'].value_counts().index[0:2]       
new_index = ['Neighbourhood Group Cleansed','Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Beds', 'Bed Type', 'Cancellation Policy','A/C_NO', 'A/C_SI', 'Heat_NO', 'Heat_SI', 'Sec_Dep_NO', 'Sec_Dep_SI','Price']   
#Usamos la unción regroup_values para cambiar los nombres de los niveles 

regroup_values(df_test,'Property Type',list_index_prop_type)
regroup_values(df_test,'Cancellation Policy',list_index_canc_Pol, new_value='strict') 
regroup_values(df_test,'Bed Type',list_index_bed_type)




df_test =  df_test.reindex(columns = new_index)
columns =  ['Neighbourhood_Group_Cleansed',
       'Property_Type', 'Room_Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
       'Beds', 'Bed_Type', 'Cancellation_Policy',
       'A/C_NO', 'A/C_SI', 'Heat_NO', 'Heat_SI', 'Sec_Dep_NO', 'Sec_Dep_SI','Price']
df_test.columns = columns
 
df_test = df_test.dropna()   
y_test = df_test['Price']                 # nos quedamos con la última columna, price
X_test = df_test.drop('Price',axis =1) # nos quedamos con el resto
X_test = main_encoder_categorical.transform(X_test)#Realizamos la trasnformación de las variables categóricas con el fit de train

y_test= y_test.dropna()
X_test= X_test.dropna()   

X_test = scaler.transform(X_test) #escalamos el X_test
print(f'Tras la trasnformación nos queda un conjunto de test con {X_test.shape[0]} filas y {X_test.shape[1]} columnas')
# Out:
# Tras la trasnformación nos queda un conjunto de test con 2627 filas y 15 columnas

# %% [markdown]
# **Ahora vamos a realizar el entrenamiento de diferentes algoritmos para ver cual es el que mejor resultados da**

# %% [markdown]
# **Regresión lineal**

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

# predicción train
y_predict_lr_train = lr.predict(X_train)
mse_lr_train = mean_squared_error(y_train, y_predict_lr_train)
rmse_lr_train = mean_absolute_error(y_train, y_predict_lr_train)
r2_train_lr = lr.score(X_train, y_train)
# predicción test
y_predict_lr_test = lr.predict(X_test)
w = lr.coef_
mse_lr_test = mean_squared_error(y_test, y_predict_lr_test)
rmse_lr_test = mean_absolute_error(y_test, y_predict_lr_test)
r2_test_lr = lr.score(X_test, y_test)
print('---------------------------------------------')
print('Valores de los coeficientes:\n')
for wi,col in zip(w, columns):
    print(col, round(wi,6))  
print('\n---------------------------------------------\n')
print(f'MSE Lasso (train) ={round(mse_lr_train,2)}')
print(f'RMSE Lasso (train) ={round(rmse_lr_train,2)}')
print(f'R2 (train) = {round(r2_train_lr,2)}')
print('\n---------------------------------------------\n')
print(f'MSE Lasso (test) ={round(mse_lr_test,2)}')
print(f'RMSE Lasso (test) ={round(rmse_lr_test,2)}')
print(f'R2 (test) = {round(r2_test_lr,2)}')
print('---------------------------------------------')
# Out:
# ---------------------------------------------
# Valores de los coeficientes:
#
# Neighbourhood_Group_Cleansed 6.984037
# Property_Type 0.033118
# Room_Type 14.441818
# Accommodates 12.056849
# Bathrooms 10.160593
# Bedrooms 13.87473
# Beds -1.623309
# Bed_Type 0.494132
# Cancellation_Policy -0.362758
# A/C_NO -3.004258
# A/C_SI 3.004258
# Heat_NO 0.316318
# Heat_SI -0.316318
# Sec_Dep_NO 1.415978
# Sec_Dep_SI -1.415978
#
# ---------------------------------------------
#
# MSE Lasso (train) =1690.8
# RMSE Lasso (train) =22.24
# R2 (train) = 0.47
#
# ---------------------------------------------
#
# MSE Lasso (test) =1419.62
# RMSE Lasso (test) =21.64
# R2 (test) = 0.52
# ---------------------------------------------

# %% [markdown]
# **Regularización de Lasso**

# %%
alpha_vector = np.logspace(-10,1,25)

param_grid = {'alpha': alpha_vector }
grid_lasso = GridSearchCV(Lasso(), scoring= 'neg_mean_squared_error', param_grid=param_grid, cv = 5)
grid_lasso.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid_lasso.best_score_))
print("best parameters: {}".format(grid_lasso.best_params_))

scores = -1*np.array(grid_lasso.cv_results_['mean_test_score'])
plt.semilogx(alpha_vector,scores,'-o')
plt.xlabel('alpha',fontsize=16)
plt.ylabel('5-Fold MSE')
plt.show()
# Out:
# best mean cross-validation score: -1705.103
# best parameters: {'alpha': 0.4216965034285822}

# %%
alpha_optimo = grid_lasso.best_params_['alpha']
lasso = Lasso(alpha = alpha_optimo).fit(X_train,y_train)
# predicción train
y_predict_lasso_train = lasso.predict(X_train)
mse_lasso_train = mean_squared_error(y_train, y_predict_lasso_train)
rmse_lasso_train = mean_absolute_error(y_train, y_predict_lasso_train)
r2_train_lasso = lasso.score(X_train, y_train)
# predicción test
y_predict_lasso_test = lasso.predict(X_test)
w = lasso.coef_
mse_lasso_test = mean_squared_error(y_test, y_predict_lasso_test)
rmse_lasso_test = mean_absolute_error(y_test, y_predict_lasso_test)
r2_test_lasso = lasso.score(X_test, y_test)
print('---------------------------------------------')
print('Valores de los coeficientes:\n')
for wi,col in zip(w, columns):
    print(col, round(wi,6))  
print('\n---------------------------------------------\n')
print(f'MSE Lasso (train) ={round(mse_lasso_train,2)}')
print(f'RMSE Lasso (train) ={round(rmse_lasso_train,2)}')
print(f'R2 (train) = {round(r2_train_lasso,2)}')
print('\n---------------------------------------------\n')
print(f'MSE Lasso (test) ={round(mse_lasso_test,2)}')
print(f'RMSE Lasso (test) ={round(rmse_lasso_test,2)}')
print(f'R2 (test) = {round(r2_test_lasso,2)}')
print('---------------------------------------------')
# Out:
# ---------------------------------------------
# Valores de los coeficientes:
#
# Neighbourhood_Group_Cleansed 6.646165
# Property_Type 0.0
# Room_Type 14.119312
# Accommodates 10.809008
# Bathrooms 9.657039
# Bedrooms 13.376055
# Beds -0.0
# Bed_Type 0.099543
# Cancellation_Policy -0.0
# A/C_NO -5.61017
# A/C_SI 0.0
# Heat_NO 0.113914
# Heat_SI -0.0
# Sec_Dep_NO 2.135475
# Sec_Dep_SI -0.0
#
# ---------------------------------------------
#
# MSE Lasso (train) =1693.13
# RMSE Lasso (train) =22.03
# R2 (train) = 0.47
#
# ---------------------------------------------
#
# MSE Lasso (test) =1420.93
# RMSE Lasso (test) =21.46
# R2 (test) = 0.52
# ---------------------------------------------

# %% [markdown]
# **Regularización Ridge**

# %%
# df_numeric = df.dropna().select_dtypes(include=['float64', 'int64'])
alpha_vector = np.logspace(-15,15,50)
param_grid = {'alpha': alpha_vector }
grid = GridSearchCV(Ridge(), scoring= 'neg_mean_squared_error', param_grid=param_grid, cv = 5)
grid.fit(X_train,y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = -1*np.array(grid.cv_results_['mean_test_score'])
plt.semilogx(alpha_vector,scores,'-o')
plt.xlabel('alpha',fontsize=16)
plt.ylabel('5-Fold MSE')
plt.show()
# Out:
# best mean cross-validation score: -1705.448
# best parameters: {'alpha': 138.9495494373136}

# %%
alpha_optimo = grid.best_params_['alpha']

ridge = Ridge(alpha = alpha_optimo).fit(X_train,y_train)

# predicción train
y_predict_ridge_train = ridge.predict(X_train)
mse_ridge_train = mean_squared_error(y_train, y_predict_ridge_train)
rmse_ridge_train = mean_absolute_error(y_train, y_predict_ridge_train)
r2_train_ridge = ridge.score(X_train, y_train)
# predicción test
y_predict_ridge_test = ridge.predict(X_test)
w = ridge.coef_
mse_ridge_test = mean_squared_error(y_test, y_predict_ridge_test)
rmse_ridge_test = mean_absolute_error(y_test, y_predict_ridge_test)
r2_test_ridge = ridge.score(X_test, y_test)
print('---------------------------------------------')
print('Valores de los coeficientes:\n')
for wi,col in zip(w, columns):
    print(col, round(wi,6))  
print('\n---------------------------------------------\n')
print(f'MSE Lasso (train) ={round(mse_ridge_train,2)}')
print(f'RMSE Lasso (train) ={round(rmse_ridge_train,2)}')
print(f'R2 (train) = {round(r2_train_ridge,2)}')
print('\n---------------------------------------------\n')
print(f'MSE Lasso (test) ={round(mse_ridge_test,2)}')
print(f'RMSE Lasso (test) ={round(rmse_ridge_test,2)}')
print(f'R2 (train) = {round(r2_test_ridge,2)}')
print('---------------------------------------------')
# Out:
# ---------------------------------------------
# Valores de los coeficientes:
#
# Neighbourhood_Group_Cleansed 6.93596
# Property_Type 0.088688
# Room_Type 14.247734
# Accommodates 11.721222
# Bathrooms 10.018699
# Bedrooms 13.648798
# Beds -1.104781
# Bed_Type 0.491446
# Cancellation_Policy -0.3156
# A/C_NO -3.023626
# A/C_SI 3.023626
# Heat_NO 0.304032
# Heat_SI -0.304032
# Sec_Dep_NO 1.355677
# Sec_Dep_SI -1.355677
#
# ---------------------------------------------
#
# MSE Lasso (train) =1690.96
# RMSE Lasso (train) =22.18
# R2 (train) = 0.47
#
# ---------------------------------------------
#
# MSE Lasso (test) =1419.27
# RMSE Lasso (test) =21.59
# R2 (train) = 0.52
# ---------------------------------------------

# %% [markdown]
# **Random Forest**

# %%
# grid search
maxDepth = range(1,15)
tuned_parameters = {'max_depth': maxDepth}

grid_rf = GridSearchCV(RandomForestClassifier(random_state=0, n_estimators=200, max_features='sqrt'), param_grid=tuned_parameters,cv=10, verbose=1) 
grid_rf.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid_rf.best_score_))
print("best parameters: {}".format(grid_rf.best_params_))

scores = np.array(grid_rf.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('10-fold ACC')

plt.show()
# Out:
# Fitting 10 folds for each of 14 candidates, totalling 140 fits
# best mean cross-validation score: 0.111
# best parameters: {'max_depth': 10}

# %%
maxDepthOptimo = grid_rf.best_params_['max_depth']
bagModel = RandomForestClassifier(max_depth=maxDepthOptimo,n_estimators=200,max_features='sqrt').fit(X_train,y_train)
modelo_final = grid_rf.best_estimator_
y_predict__train_rf = modelo_final.predict(X = X_train)
y_predict_test_rf = modelo_final.predict(X = X_test)
rmse_train_rf = mean_squared_error(
            y_true  = y_train,
            y_pred  = y_predict__train_rf,
            squared = False
          )

rmse_test_rf = mean_squared_error(
            y_true  = y_test,
            y_pred  = y_predict__test_rf,
            squared = False
          )
r2_train_rf = r2_score(y_train,y_predict__train_rf)  
r2_test_rf = r2_score(y_test,y_predict_test_rf)  

print('\n---------------------------------------------\n')
print("Random Forest accuracy (train): ",round(bagModel.score(X_train,y_train),2))
print(f"RMSE (train: {round(rmse_train_rf,2)}")
print(f"R2 (train): {round(r2_train_rf,2)}")
print('\n---------------------------------------------\n')
print("Random Forest accuracy (Test): ",round(bagModel.score(X_test,y_test),2))
print(f"RMSE (test: {round(rmse_test_rf,2)}")
print(f"R2 (test): {round(r2_test_rf,2)}")
print('\n---------------------------------------------\n')
# Out:
# ---------------------------------------------
#
# Random Forest (train):  0.35
# RMSE (train: 31.83
# R2 (train): 0.68
#
# ---------------------------------------------
#
# Random Forest (Test):  0.12
# RMSE (train: 40.61
# R2 (train): 0.44
#
# ---------------------------------------------

# %% [markdown]
# **BoostingRegressor**

# %%
Niterations = [500,1000,1500,2000]
learningRate = [0.1,0.05,0.01]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate }
grid_br = GridSearchCV(GradientBoostingRegressor(random_state=0, max_depth=3), param_grid=param_grid, cv = 5, verbose=2)
grid_br.fit(X_train, y_train)
print('\n---------------------------------------------\n')
print("best mean cross-validation score: {:.3f}".format(grid_br.best_score_))
print("best parameters: {}".format(grid_br.best_params_))
print('\n---------------------------------------------\n')
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   2.8s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   2.9s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   2.6s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   2.8s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   2.8s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   6.1s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   6.0s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   5.5s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   5.6s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   5.5s
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time=   8.5s
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time=   9.2s
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time=   8.9s
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time=   9.6s
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time=   9.0s
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time=  12.1s
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time=  11.6s
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time=  11.3s
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time=  11.1s
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time=  11.2s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   2.6s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   2.5s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   2.7s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   2.7s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   2.7s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   6.0s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   6.0s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   5.9s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   5.8s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   6.2s
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time=   9.2s
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time=   9.1s
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time=   9.0s
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time=   9.1s
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time=   9.0s
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time=  11.2s
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time=  11.6s
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time=  11.9s
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time=  12.3s
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time=  12.2s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   3.0s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   2.9s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   3.0s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   2.8s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   2.7s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   6.3s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   6.1s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   6.3s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   6.4s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   6.1s
# [CV] END ..............learning_rate=0.01, n_estimators=1500; total time=   9.0s
# [CV] END ..............learning_rate=0.01, n_estimators=1500; total time=   9.1s
# [CV] END ..............learning_rate=0.01, n_estimators=1500; total time=   8.7s
# [CV] END ..............learning_rate=0.01, n_estimators=1500; total time=   8.8s
# [CV] END ..............learning_rate=0.01, n_estimators=1500; total time=   8.7s
# [CV] END ..............learning_rate=0.01, n_estimators=2000; total time=  11.9s
# [CV] END ..............learning_rate=0.01, n_estimators=2000; total time=  12.0s
# [CV] END ..............learning_rate=0.01, n_estimators=2000; total time=  11.9s
# [CV] END ..............learning_rate=0.01, n_estimators=2000; total time=  11.9s
# [CV] END ..............learning_rate=0.01, n_estimators=2000; total time=  12.2s
#
# ---------------------------------------------
#
# best mean cross-validation score: 0.556
# best parameters: {'learning_rate': 0.01, 'n_estimators': 1000}
#
# ---------------------------------------------

# %%
lrOptimo = grid_br.best_params_['learning_rate']
neOptimo = grid_br.best_params_['n_estimators']
bt = GradientBoostingRegressor(random_state=0, max_depth=3,learning_rate=lrOptimo, n_estimators=neOptimo)
bt.fit(X_train,y_train)

error = 1-grid_br.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# iteraciones')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(bt.score(X_train,y_train),bt.score(X_test,y_test)))
plt.grid()
plt.show()

# %%
modelo_final_boosting = grid_br.best_estimator_
y_predict_train_br = modelo_final_boosting.predict(X = X_train)
y_predict_test_br = modelo_final_boosting.predict(X = X_test)
rmse_train_br = mean_squared_error(
            y_true  = y_train,
            y_pred  = y_predict__train_br,
            squared = False
          )

rmse_test_br = mean_squared_error(
            y_true  = y_test,
            y_pred  = y_predict_test_br,
            squared = False
          )
r2_train_br = r2_score(y_train,y_predict__train_br)  
r2_test_br = r2_score(y_test,y_predict_test_br)  

print('\n---------------------------------------------\n')
print("Boosting (train): ",round(bt.score(X_train,y_train),2))
print(f"RMSE (train: {round(rmse_train_br,2)}")
print(f"R2 (train): {round(r2_train_br,2)}")
print('\n---------------------------------------------\n')
print("Random Forest (Test): ",round(bt.score(X_test,y_test),2))
print(f"RMSE (test: {round(rmse_test_br,2)}")
print(f"R2 (test): {round(r2_test_br,2)}")
print('\n---------------------------------------------\n')
# Out:
# ---------------------------------------------
#
# Boosting (train):  0.61
# RMSE (train: 35.32
# R2 (train): 0.61
#
# ---------------------------------------------
#
# Random Forest (Test):  0.57
# RMSE (test: 35.59
# R2 (test): 0.57
#
# ---------------------------------------------

# %%
importances = bt.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),feature_names[indices])
plt.show()

# %% [markdown]
# # Conclusiones

# %% [markdown]
# **Vamos a comparar el RMSE y el R2 de los 5 modelos analizados**

# %%
analisis_modelos = pd.DataFrame({
                        'modelo': ['Regresión Lineal', 'Lasso', 'Ridge','Random forest', 'Gradient boosting'],
                        'rmse': [rmse_lr_test, rmse_lasso_test, rmse_ridge_test, rmse_test_rf, rmse_test_br],
                        'r2': [r2_test_lr,r2_test_lasso,r2_test_ridge,r2_test_rf,r2_test_br]
                     })
analisis_modelos = analisis_modelos.sort_values('rmse', ascending=False)


plt.figure(figsize=(12, 8))
sns.barplot(x=analisis_modelos['rmse'], y=analisis_modelos['modelo'], palette='Reds')
plt.title('Comparación de RMSE de test modelos', fontsize=14)
plt.xlabel('Test rmse', fontsize=12)
plt.ylabel('Modelos', fontsize=12)
# for i in range(len(error_modelos['rmse'])):
#     plt.text(x = i-0.3, y = error_modelos['rmse'][i]+0.05, s = error_modelos['rmse'][i], size = 10)
plt.show()

analisis_modelos = analisis_modelos.sort_values('r2', ascending=False)
plt.figure(figsize=(16, 8))
sns.barplot(x=analisis_modelos['r2'], y=analisis_modelos['modelo'], palette='Greens')
plt.title('Comparación de R2 de test modelos', fontsize=14)
plt.xlabel('Test R2', fontsize=12)
plt.ylabel('Modelos', fontsize=12)
plt.show()

analisis_modelos
# Out:
#               modelo       rmse        r2
# 4  Gradient boosting  35.592983  0.568121
# 2              Ridge  21.590193  0.516163
# 0   Regresión Lineal  21.643915  0.516046
# 1              Lasso  21.461597  0.515596
# 3      Random forest  40.610262  0.437782

# %% [markdown]
# **Tras entrenar varios modelos, comprobamos que ninguno de ellos es capaz de realizar una predicción con una alta precisión del precio de los alojamientos. En este caso los modelos que mejor resultado dan es la regresión lineal con las regularizaciones de Lasso y Ridge. Los modelos con arboles arrojan un error mayor y una baja precisión**
